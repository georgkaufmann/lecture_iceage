# %%
import numpy as np

# %%
t = np.linspace(0,5000,501)
T1   = 1000.
tau1 = 300.
tau2 = 150.
R0   = 0.00207
N0   = 5.
Neq  = 1.

R1n = np.zeros(len(t))
R2n = np.zeros(len(t))
R3n = np.zeros(len(t))
R1n[0] = R0
R2n[0] = R0
R3n[0] = R0
Nold = N0
for i in range(1,len(t)):
    N  = (N0-Neq)*np.exp(-t[i]/tau1) + Neq
    dN = 1/tau1*(N0-Neq)*np.exp(-t[i]/tau1)
    print (i,t[i],N,dN,N-Nold)
    Nold = N
# Out:
# 1 10.0 4.868864401928024 0.012896214673093412 -0.1311355980719764
# 2 20.0 4.742027940126471 0.012473426467088237 -0.1268364618015525
# 3 30.0 4.619349672143838 0.012064498907146127 -0.12267826798263304
# 4 40.0 4.5006932761717895 0.011668977587239301 -0.11865639597204858
# 5 50.0 4.385926899562456 0.011286422998541523 -0.11476637660933342
# 6 60.0 4.274923012311927 0.010916410041039758 -0.11100388725052923
# 7 70.0 4.167558265347127 0.010558527551157089 -0.1073647469647998
# 8 80.0 4.063713353458595 0.010212377844861982 -0.10384491188853229
# 9 90.0 3.9632728827268715 0.00987757627575624 -0.10044047073172324
# 10 100.0 3.866125242295157 0.009553750807650524 -0.09714764043171442
# 11 110.0 3.772162480345766 0.009240541601152555 -0.09396276194939102
# 12 120.0 3.6812801841425573 0.008937600613808525 -0.09088229620320876
# 13 130.0 3.593377364006039 0.008644591213353463 -0.0879028201365184
# 14 140.0 3.5083563410922243 0.008361187803640749 -0.08502102291381464
# ...
